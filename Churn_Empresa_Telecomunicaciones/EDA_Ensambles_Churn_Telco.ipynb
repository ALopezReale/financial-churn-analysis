# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("WA_Fn-UseC_-Telco-Customer-Churn.csv")

# %%
pd.set_option("display.max_columns", None)
df.sample(5)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 3063  1666-JXLKU  Female              0      No         No      37
# 3081  6376-GAHQE    Male              0      No         No       4
# 5938  9971-ZWPBF    Male              1     Yes        Yes      34
# 5261  1409-PHXTF    Male              1     Yes         No      54
# 3212  0585-EGDDA    Male              0     Yes         No      40
#
#      PhoneService MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 3063          Yes           Yes     Fiber optic             No           No
# 3081          Yes            No     Fiber optic             No           No
# 5938          Yes           Yes     Fiber optic             No          Yes
# 5261          Yes           Yes     Fiber optic             No          Yes
# 3212          Yes            No     Fiber optic             No          Yes
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 3063              Yes          No         Yes             Yes  Month-to-month
# 3081               No          No         Yes              No  Month-to-month
# 5938              Yes         Yes         Yes             Yes  Month-to-month
# 5261              Yes         Yes         Yes             Yes        Two year
# 3212              Yes          No          No              No  Month-to-month
#
#      PaperlessBilling     PaymentMethod  MonthlyCharges TotalCharges Churn
# 3063              Yes  Electronic check          100.05      3810.55    No
# 3081               No  Electronic check           77.85        299.2   Yes
# 5938              Yes  Electronic check          108.90       3625.2    No
# 5261              Yes  Electronic check          110.45      6077.75    No
# 3212              Yes  Electronic check           80.00      3168.75    No

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='str')

# %%
# Convertimos los Sí a 1 y los No a 0
y = df['Churn'].map({'Yes':1, 'No':0})

# %%
y.value_counts(1)
# Out:
# Churn
# 0    0.73463
# 1    0.26537
# Name: proportion, dtype: float64

# %% [markdown]
# Un 26,5% abandonan.

# %% [markdown]
# # Encoding

# %%
# seleccionamos primero solo las columnas que nos van a servir más
subset = [
'customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
       'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
       'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
       'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
       'PaymentMethod', 'MonthlyCharges', 'TotalCharges',
]

# %%
# definimos las features y el target
X = df[subset] # features
y = df['Churn'] # target

# dividimos en train y test
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.2, # qué porcentaje del dataset destinaremos para testear
    random_state=42,
    stratify=y              # la variable objetivo, que es Exited
)

print("X_train:", X_train.shape)
print(y_train.value_counts(1))

print("X_test:", X_test.shape)
print(y_test.value_counts(1))
# Out:
# X_train: (5634, 20)
# Churn
# No     0.734647
# Yes    0.265353
# Name: proportion, dtype: float64
# X_test: (1409, 20)
# Churn
# No     0.734564
# Yes    0.265436
# Name: proportion, dtype: float64
