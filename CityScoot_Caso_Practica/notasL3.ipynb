# %% [markdown]
# El get.dummies es el reemplazo para el One Hot Encoder.

# %% [markdown]
# # Cómo funciona skit-learn
# 1. Definir o instanciar
# 2. Entrenar
# 3. Predecir

# %% [markdown]
# class_weigth: balanced. Para balancear el dato con menor peso.

# %% [markdown]
# n_jobs para usar todos los núcleos.

# %% [markdown]
# # Entrenar el modelo
# se usa el método .fit.
# predict_proba - para predecir las probabilidades de que de 0 o que de 1.
